# %%
# Terminal
# pip install scikit-learn==1.4.2
# Restart Kernel

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
import scipy.special

def generate_features(n_samples=1000):
    """
    Generate mixed data types: 15 continuous, 5 discrete, 5 categorical
    """
    # generate continuous features
    rho = 0.2
    mus = np.random.uniform(10, 50, 15)
    sigmas = np.random.uniform(2, 10, 15)

    # covariance matrix
    cov = np.zeros((15, 15))
    np.fill_diagonal(cov, sigmas**2)
    for i in range(15):
        for j in range(i+1, 15):
            cov[i, j] = cov[j, i] = rho * sigmas[i] * sigmas[j]
            
    continuous_data = np.random.multivariate_normal(mus, cov, size=n_samples)
    continuous_features = {}
    for i in range(15):
        continuous_features[f'continuous_{i}'] = continuous_data[:, i]

    # generate discrete features
    discrete_features = {}
    lambdas = [2, 3, 4, 5, 6] 
    for i in range(5):
        discrete_features[f'discrete_{i}'] = np.random.poisson(lambdas[i], n_samples)

    # generate categorical features
    categorical_features = {}
    for i in range(5):
        if i < 4:
            # 4 binary features 
            categories = ['No', 'Yes']
            prob = np.random.uniform(0.3, 0.7)
            probs = [1-prob, prob]
            categorical_features[f'categorical_{i}'] = np.random.choice(categories, size=n_samples, p=probs)
        else: 
            # 1 multinomial feature 
            categories = ['Level_A', 'Level_B', 'Level_C']
            probs = [0.4, 0.35, 0.25]  
            categorical_features[f'categorical_{i}'] = np.random.choice(categories, size=n_samples, p=probs)
    
    return continuous_features, discrete_features, categorical_features

def standardise_features(cont_features, disc_features, cat_features):
    """
    Standardise numerical features and one-hot encode categorical features.
    """
    # create initial dataframe
    df = pd.DataFrame(cont_features)
    for col, values in disc_features.items():
        df[col] = values
    for col, values in cat_features.items():
        df[col] = values
    
    # get column lists
    cont_cols = list(cont_features.keys())
    disc_cols = list(disc_features.keys())
    cat_cols = list(cat_features.keys())
    
    # standardise continuous and discrete features
    scaler = StandardScaler()
    df_scaled_cont_disc = pd.DataFrame(
        scaler.fit_transform(df[cont_cols + disc_cols]),
        columns=cont_cols + disc_cols
    )
    
    # one-hot encode categorical features
    encoder = OneHotEncoder(sparse_output=False, drop='first')  
    df_encoded_cat = pd.DataFrame(
        encoder.fit_transform(df[cat_cols]),
        columns=encoder.get_feature_names_out(cat_cols)
    )
    df_encoded_cat = df_encoded_cat.astype(int)
    
    # combine all features
    df_processed = pd.concat([df_scaled_cont_disc, df_encoded_cat], axis=1)
    
    return df_processed, cont_cols, disc_cols, cat_cols

def assign_feature_importance(df_processed):
    """
    Assign importance weights to features.
    """
    all_features = df_processed.columns.to_list()
    
    # define importance categories
    high_importance = ['continuous_0', 'continuous_3', 'continuous_12', 'discrete_1', 'discrete_3', 'categorical_0_Yes', 'categorical_2_Yes']
    medium_importance = ['continuous_1', 'continuous_5', 'continuous_9', 'continuous_11', 'continuous_13', 'discrete_0', 'discrete_4', 'categorical_1_Yes', 'categorical_4_Level_C']
    low_importance = [col for col in all_features if col not in high_importance + medium_importance]
    
    # assign weights with random signs
    def random_weight(low, high):
        weight = np.random.uniform(low, high)
        sign = np.random.choice([-1, 1])
        return np.round(sign * weight, 2)

    feature_weights = {}
    for f in high_importance:
        feature_weights[f] = random_weight(2.0, 3.0)
    for f in medium_importance:
        feature_weights[f] = random_weight(1.0, 2.0)
    for f in low_importance:
        feature_weights[f] = random_weight(0.0, 1.0)

    return feature_weights, high_importance, medium_importance, low_importance

def generate_target(df_processed, feature_weights):
    """
    Generate binary target variable using a logistic function.
    """
    all_features = df_processed.columns.to_list()
    X = df_processed[all_features].values
    B = np.array([feature_weights[f] for f in all_features])
    
    # mean predicted probability for a given intercept
    def calculate_mean_prob(intercept):
        logit_p = X @ B + intercept
        p = scipy.special.expit(logit_p)
        return p.mean()

    # binary search to balance classes
    low, high = -10.0, 10.0
    for _ in range(25):
        mid = (low + high)/2
        if calculate_mean_prob(mid) > 0.5:
            high = mid
        else:
            low = mid 
    intercept = (low + high) / 2

    # generate target
    logit_p = X @ B + intercept
    p = scipy.special.expit(logit_p)
    y = np.random.binomial(1, p)
    
    # add target to dataframe
    synthetic_data = df_processed.copy()
    synthetic_data['target'] = y
    
    return synthetic_data

def check_data_quality(synthetic_data):
    """
    Check data quality: types, target distribution balance, multicollinearity.
    """
    # check data types
    data_types = synthetic_data.dtypes
    
    # check target distribution
    target_balance = synthetic_data['target'].mean()
    
    # check multicollinearity
    X_vif = synthetic_data.drop(columns=['target'])
    vif_data = pd.DataFrame()
    vif_data['feature'] = X_vif.columns
    vif_data['VIF'] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
    max_vif = vif_data['VIF'].max()
    
    quality_report = {
        'target_balance': target_balance,
        'max_vif': max_vif,
        'num_features': len(synthetic_data.columns) - 1
    }
    
    return quality_report
    
def split_and_save_data(synthetic_data, iteration, output_dir="data/complete", random_state=57):
    """
    Split data into train and test sets and save to files.
    """
    # stratified split data
    train_data, test_data = train_test_split(
        synthetic_data, 
        test_size=0.3, 
        random_state=random_state, 
        stratify=synthetic_data['target']
    )
    
    # create iteration directory path
    iter_dir = f"{output_dir}/iteration_{iteration}"
    os.makedirs(iter_dir, exist_ok=True)
    
    # save files
    train_data.to_csv(f"{iter_dir}/train_complete.csv", index=False)
    test_data.to_csv(f"{iter_dir}/test_complete.csv", index=False)
    
    print(f"Train shape: {train_data.shape}, Test shape: {test_data.shape}")
    print(f"Train target distribution: {train_data['target'].value_counts(normalize=True)}")
    print(f"Test target distribution: {test_data['target'].value_counts(normalize=True)}")
    
    return train_data, test_data

def generate_synthetic_dataset(iteration, random_seed, n_samples=1000):
    """
    Generate a complete synthetic dataset.
    """
    print(f"Generating synthetic dataset for iteration {iteration} with seed {random_seed}")

    # set random seed for replicability
    np.random.seed(random_seed)
    
    # 1. generate features
    cont_features, disc_features, cat_features = generate_features(n_samples)
    # 2. scale and encode features
    df_processed, cont_cols, disc_cols, cat_cols = standardise_features(cont_features, disc_features, cat_features)
    # 3. assign importance weights
    feature_weights, high, medium, low = assign_feature_importance(df_processed)
    # 4. create the target
    synthetic_data = generate_target(df_processed, feature_weights)
    # 5. check data quality
    quality_report = check_data_quality(synthetic_data)
    print(f"Data quality report: {quality_report}")
    # 6. split and save
    train_data, test_data = split_and_save_data(
        synthetic_data, 
        iteration=iteration, 
        output_dir="data/complete", 
        random_state=random_seed
    )
    
    return train_data, test_data, synthetic_data

if __name__ == "__main__":
    for seed in range(1, 101):
    
        # generate dataset
        train_data, test_data, synthetic_data = generate_synthetic_dataset(
            iteration=seed, 
            random_seed=seed,
            n_samples=1000
        )
        print(f"\n")

    print(f"Successfully generated synthetic data for 100 iterations.")
# Out:
# Generating synthetic dataset for iteration 1 with seed 1
# Data quality report: {'target_balance': 0.518, 'max_vif': 2.3119640615166612, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.518571
# 0    0.481429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.516667
# 0    0.483333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 2 with seed 2
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.116437183619273, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 3 with seed 3
# Data quality report: {'target_balance': 0.488, 'max_vif': 1.791830713508348, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.511429
# 1    0.488571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.513333
# 1    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 4 with seed 4
# Data quality report: {'target_balance': 0.494, 'max_vif': 1.8844277503136475, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 5 with seed 5
# Data quality report: {'target_balance': 0.503, 'max_vif': 1.5910233207390625, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 6 with seed 6
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.3208511256743254, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 7 with seed 7
# Data quality report: {'target_balance': 0.506, 'max_vif': 1.4984265645067072, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.505714
# 0    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 8 with seed 8
# Data quality report: {'target_balance': 0.5, 'max_vif': 2.2872696901523293, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 9 with seed 9
# Data quality report: {'target_balance': 0.495, 'max_vif': 2.030455199792706, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.504286
# 1    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 10 with seed 10
# Data quality report: {'target_balance': 0.489, 'max_vif': 2.388844721519094, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.511429
# 1    0.488571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 11 with seed 11
# Data quality report: {'target_balance': 0.493, 'max_vif': 1.7806973086823672, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 12 with seed 12
# Data quality report: {'target_balance': 0.512, 'max_vif': 2.005883687422143, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.511429
# 0    0.488571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 13 with seed 13
# Data quality report: {'target_balance': 0.5, 'max_vif': 2.0754439992924363, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 14 with seed 14
# Data quality report: {'target_balance': 0.503, 'max_vif': 1.982502985615159, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 15 with seed 15
# Data quality report: {'target_balance': 0.504, 'max_vif': 1.984399739913191, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 16 with seed 16
# Data quality report: {'target_balance': 0.502, 'max_vif': 2.120628997770078, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 17 with seed 17
# Data quality report: {'target_balance': 0.493, 'max_vif': 1.9048795380798478, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 18 with seed 18
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.516218684218219, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 19 with seed 19
# Data quality report: {'target_balance': 0.507, 'max_vif': 2.159224522855007, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.507143
# 0    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 20 with seed 20
# Data quality report: {'target_balance': 0.507, 'max_vif': 2.06419417627659, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.507143
# 0    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 21 with seed 21
# Data quality report: {'target_balance': 0.505, 'max_vif': 2.6207584393993764, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 22 with seed 22
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.719776526136207, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 23 with seed 23
# Data quality report: {'target_balance': 0.49, 'max_vif': 1.7010165409874185, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 24 with seed 24
# Data quality report: {'target_balance': 0.491, 'max_vif': 2.1150438815109247, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 25 with seed 25
# Data quality report: {'target_balance': 0.514, 'max_vif': 2.015560293783073, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.514286
# 0    0.485714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 26 with seed 26
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.4845348855039027, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 27 with seed 27
# Data quality report: {'target_balance': 0.49, 'max_vif': 2.123334493656953, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 28 with seed 28
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.0738286552844984, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 29 with seed 29
# Data quality report: {'target_balance': 0.504, 'max_vif': 1.828976240497858, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 30 with seed 30
# Data quality report: {'target_balance': 0.504, 'max_vif': 1.9961356062285855, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 31 with seed 31
# Data quality report: {'target_balance': 0.508, 'max_vif': 2.4664866186166976, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.508571
# 0    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 32 with seed 32
# Data quality report: {'target_balance': 0.492, 'max_vif': 2.1795920221651732, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 33 with seed 33
# Data quality report: {'target_balance': 0.509, 'max_vif': 2.4249973813300594, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.508571
# 0    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.51
# 0    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 34 with seed 34
# Data quality report: {'target_balance': 0.495, 'max_vif': 1.819363619595975, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 35 with seed 35
# Data quality report: {'target_balance': 0.495, 'max_vif': 1.822481156358645, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 36 with seed 36
# Data quality report: {'target_balance': 0.508, 'max_vif': 2.6084824629960286, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.508571
# 0    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 37 with seed 37
# Data quality report: {'target_balance': 0.513, 'max_vif': 1.7002820221104133, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.512857
# 0    0.487143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 38 with seed 38
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.025907356555034, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 39 with seed 39
# Data quality report: {'target_balance': 0.497, 'max_vif': 2.3316480543811036, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.502857
# 1    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 40 with seed 40
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.1231808606106095, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 41 with seed 41
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.1201488750390105, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 42 with seed 42
# Data quality report: {'target_balance': 0.487, 'max_vif': 2.0444560833243823, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.512857
# 1    0.487143
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.513333
# 1    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 43 with seed 43
# Data quality report: {'target_balance': 0.492, 'max_vif': 2.2646143793439584, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 44 with seed 44
# Data quality report: {'target_balance': 0.492, 'max_vif': 2.0364139183582863, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 45 with seed 45
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.0029776845233807, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 46 with seed 46
# Data quality report: {'target_balance': 0.494, 'max_vif': 1.7734881339236583, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 47 with seed 47
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.3359763111404725, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 48 with seed 48
# Data quality report: {'target_balance': 0.501, 'max_vif': 2.1114996726865223, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 49 with seed 49
# Data quality report: {'target_balance': 0.493, 'max_vif': 1.715900149886333, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 50 with seed 50
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.1721050609517123, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 51 with seed 51
# Data quality report: {'target_balance': 0.498, 'max_vif': 1.8987199724996355, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 52 with seed 52
# Data quality report: {'target_balance': 0.508, 'max_vif': 2.335663706467096, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.508571
# 0    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 53 with seed 53
# Data quality report: {'target_balance': 0.497, 'max_vif': 1.945630632841687, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.502857
# 1    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 54 with seed 54
# Data quality report: {'target_balance': 0.5, 'max_vif': 2.0420556505099645, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 55 with seed 55
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.1697270000020232, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 56 with seed 56
# Data quality report: {'target_balance': 0.493, 'max_vif': 2.419724874224945, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 57 with seed 57
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.3289454328713335, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 58 with seed 58
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.5948323284550487, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 59 with seed 59
# Data quality report: {'target_balance': 0.498, 'max_vif': 2.27233396482701, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 60 with seed 60
# Data quality report: {'target_balance': 0.507, 'max_vif': 2.47023495733598, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.507143
# 0    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 61 with seed 61
# Data quality report: {'target_balance': 0.501, 'max_vif': 1.8262616674107448, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 62 with seed 62
# Data quality report: {'target_balance': 0.501, 'max_vif': 1.808767599712639, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 63 with seed 63
# Data quality report: {'target_balance': 0.5, 'max_vif': 1.6722436337945683, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 64 with seed 64
# Data quality report: {'target_balance': 0.497, 'max_vif': 2.549956746961316, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.502857
# 1    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 65 with seed 65
# Data quality report: {'target_balance': 0.496, 'max_vif': 1.671194070841309, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.504286
# 1    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 66 with seed 66
# Data quality report: {'target_balance': 0.495, 'max_vif': 2.129310133436088, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.504286
# 1    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 67 with seed 67
# Data quality report: {'target_balance': 0.513, 'max_vif': 1.6292014775457908, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.512857
# 0    0.487143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 68 with seed 68
# Data quality report: {'target_balance': 0.504, 'max_vif': 2.1631582292536162, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 69 with seed 69
# Data quality report: {'target_balance': 0.494, 'max_vif': 2.2446999160518066, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 70 with seed 70
# Data quality report: {'target_balance': 0.483, 'max_vif': 2.273892111399841, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.517143
# 1    0.482857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.516667
# 1    0.483333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 71 with seed 71
# Data quality report: {'target_balance': 0.494, 'max_vif': 2.028820571198005, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 72 with seed 72
# Data quality report: {'target_balance': 0.49, 'max_vif': 2.19207110814503, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 73 with seed 73
# Data quality report: {'target_balance': 0.491, 'max_vif': 2.4281004338796364, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 74 with seed 74
# Data quality report: {'target_balance': 0.514, 'max_vif': 2.0947212320898214, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.514286
# 0    0.485714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 75 with seed 75
# Data quality report: {'target_balance': 0.503, 'max_vif': 1.5575835135141036, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 76 with seed 76
# Data quality report: {'target_balance': 0.508, 'max_vif': 2.155703851029052, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.508571
# 0    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 77 with seed 77
# Data quality report: {'target_balance': 0.489, 'max_vif': 2.4468154382862877, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.511429
# 1    0.488571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 78 with seed 78
# Data quality report: {'target_balance': 0.502, 'max_vif': 2.369624734428887, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 79 with seed 79
# Data quality report: {'target_balance': 0.514, 'max_vif': 2.3826333506281383, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.514286
# 0    0.485714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 80 with seed 80
# Data quality report: {'target_balance': 0.504, 'max_vif': 1.7030379101405, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 81 with seed 81
# Data quality report: {'target_balance': 0.494, 'max_vif': 2.0400055737734437, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 82 with seed 82
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.2170434192889577, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 83 with seed 83
# Data quality report: {'target_balance': 0.494, 'max_vif': 2.0394031914918447, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.505714
# 1    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 84 with seed 84
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.3296802927578124, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 85 with seed 85
# Data quality report: {'target_balance': 0.506, 'max_vif': 2.2907363779262817, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.505714
# 0    0.494286
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 86 with seed 86
# Data quality report: {'target_balance': 0.502, 'max_vif': 2.225613177695626, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.501429
# 0    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 87 with seed 87
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.229558034342285, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 88 with seed 88
# Data quality report: {'target_balance': 0.507, 'max_vif': 1.7922154448984566, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.507143
# 0    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.506667
# 0    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 89 with seed 89
# Data quality report: {'target_balance': 0.493, 'max_vif': 1.7048202102092118, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 90 with seed 90
# Data quality report: {'target_balance': 0.498, 'max_vif': 1.8737581159716525, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 91 with seed 91
# Data quality report: {'target_balance': 0.503, 'max_vif': 2.5319094159715805, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.502857
# 0    0.497143
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 92 with seed 92
# Data quality report: {'target_balance': 0.512, 'max_vif': 2.0719276713973804, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.511429
# 0    0.488571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 93 with seed 93
# Data quality report: {'target_balance': 0.491, 'max_vif': 2.3944114508608845, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.508571
# 1    0.491429
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.51
# 1    0.49
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 94 with seed 94
# Data quality report: {'target_balance': 0.504, 'max_vif': 1.915151928077864, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.504286
# 0    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.503333
# 0    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 95 with seed 95
# Data quality report: {'target_balance': 0.495, 'max_vif': 2.2615012939075188, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.504286
# 1    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 96 with seed 96
# Data quality report: {'target_balance': 0.499, 'max_vif': 2.0544168969374454, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.501429
# 1    0.498571
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 97 with seed 97
# Data quality report: {'target_balance': 0.514, 'max_vif': 1.7110613323985842, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 1    0.514286
# 0    0.485714
# Name: proportion, dtype: float64
# Test target distribution: target
# 1    0.513333
# 0    0.486667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 98 with seed 98
# Data quality report: {'target_balance': 0.496, 'max_vif': 1.6008381810861791, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.504286
# 1    0.495714
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.503333
# 1    0.496667
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 99 with seed 99
# Data quality report: {'target_balance': 0.493, 'max_vif': 1.6554308133964222, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Generating synthetic dataset for iteration 100 with seed 100
# Data quality report: {'target_balance': 0.493, 'max_vif': 2.048252363362048, 'num_features': 26}
# Train shape: (700, 27), Test shape: (300, 27)
# Train target distribution: target
# 0    0.507143
# 1    0.492857
# Name: proportion, dtype: float64
# Test target distribution: target
# 0    0.506667
# 1    0.493333
# Name: proportion, dtype: float64
#
#
# Successfully generated synthetic data for 100 iterations.
